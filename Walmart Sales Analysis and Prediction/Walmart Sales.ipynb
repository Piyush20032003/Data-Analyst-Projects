# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('WalmartSalesData.csv.csv')

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200   80.2200
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880  489.0480
# 4       Sports and travel       86.31         7  30.2085  634.3785
#
#          Date      Time      Payment    cogs  gross margin percentage  \
# 0  2019-01-05  13:08:00      Ewallet  522.83                 4.761905
# 1  2019-03-08  10:29:00         Cash   76.40                 4.761905
# ...

# %%
df2 = df.copy()

# %%
df2.columns = df2.columns.str.replace(' ','_')

# %%
df2.head()
# Out:
#     Invoice_ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product_line  Unit_price  Quantity   Tax_5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200   80.2200
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880  489.0480
# 4       Sports and travel       86.31         7  30.2085  634.3785
#
#          Date      Time      Payment    cogs  gross_margin_percentage  \
# 0  2019-01-05  13:08:00      Ewallet  522.83                 4.761905
# 1  2019-03-08  10:29:00         Cash   76.40                 4.761905
# ...

# %%
df2.columns
# Out:
# Index(['Invoice_ID', 'Branch', 'City', 'Customer_type', 'Gender',
#        'Product_line', 'Unit_price', 'Quantity', 'Tax_5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross_margin_percentage', 'gross_income',
#        'Rating'],
#       dtype='object')

# %%
##Gross margin percentage is same so we will delete the entire column
df2.drop(columns='gross_margin_percentage', inplace=True)

# %%
df2.head()
# Out:
#     Invoice_ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product_line  Unit_price  Quantity   Tax_5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200   80.2200
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880  489.0480
# 4       Sports and travel       86.31         7  30.2085  634.3785
#
#          Date      Time      Payment    cogs  gross_income  Rating
# 0  2019-01-05  13:08:00      Ewallet  522.83       26.1415     9.1
# 1  2019-03-08  10:29:00         Cash   76.40        3.8200     9.6
# ...

# %%
x =df2.corr()

# %%
import seaborn as sns
# Out:
# D:\Anaconda\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
sns.heatmap(data=x,annot=True)
# Out:
# <AxesSubplot:>

# %%
df2['Date'] = pd.to_datetime(df2['Date'])

# %%
df2['year'] = df2['Date'].dt.year
df2['month']= df2['Date'].dt.month
df2['day']= df2['Date'].dt.day

# %%
df2.head()
# Out:
#     Invoice_ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product_line  Unit_price  Quantity   Tax_5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#        Time      Payment    cogs  gross_income  Rating  year  month  day
# 0  13:08:00      Ewallet  522.83       26.1415     9.1  2019      1    5
# ...

# %%
df2.drop(columns=['year','Time'], inplace = True)

# %%
df2.drop(columns=['Date'],inplace=True)

# %%
df2.head()
# Out:
#     Invoice_ID Branch       City Customer_type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product_line  Unit_price  Quantity   Tax_5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200   80.2200
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880  489.0480
# 4       Sports and travel       86.31         7  30.2085  634.3785
#
#        Payment    cogs  gross_income  Rating  month  day
# 0      Ewallet  522.83       26.1415     9.1      1    5
# 1         Cash   76.40        3.8200     9.6      3    8
# ...

# %%
df3 = df2.copy()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
df3['Branch'] = label_encoder.fit_transform(df3['Branch'])
df3['City'] = label_encoder.fit_transform(df3['City'])
df3['Customer_type'] = label_encoder.fit_transform(df3['Customer_type'])
df3['Gender'] = label_encoder.fit_transform(df3['Gender'])
df3['Product_line'] = label_encoder.fit_transform(df3['Product_line'])
df3['Payment'] = label_encoder.fit_transform(df3['Payment'])
df3['Quantity'] = label_encoder.fit_transform(df3['Quantity'])

# %%
df3.head()
# Out:
#     Invoice_ID  Branch  City  Customer_type  Gender  Product_line  Unit_price  \
# 0  750-67-8428       0     2              0       0             3       74.69
# 1  226-31-3081       2     1              1       0             0       15.28
# 2  631-41-3108       0     2              1       1             4       46.33
# 3  123-19-1176       0     2              0       1             3       58.22
# 4  373-73-7910       0     2              1       1             5       86.31
#
#    Quantity   Tax_5%     Total  Payment    cogs  gross_income  Rating  month  \
# 0         6  26.1415  548.9715        2  522.83       26.1415     9.1      1
# 1         4   3.8200   80.2200        0   76.40        3.8200     9.6      3
# 2         6  16.2155  340.5255        1  324.31       16.2155     7.4      3
# 3         7  23.2880  489.0480        2  465.76       23.2880     8.4      1
# 4         6  30.2085  634.3785        2  604.17       30.2085     5.3      2
#
#    day
# 0    5
# 1    8
# 2    3
# ...

# %%
df3.drop(columns=['Invoice_ID'], inplace=True)

# %%
df3.head()
# Out:
#    Branch  City  Customer_type  Gender  Product_line  Unit_price  Quantity  \
# 0       0     2              0       0             3       74.69         6
# 1       2     1              1       0             0       15.28         4
# 2       0     2              1       1             4       46.33         6
# 3       0     2              0       1             3       58.22         7
# 4       0     2              1       1             5       86.31         6
#
#     Tax_5%     Total  Payment    cogs  gross_income  Rating  month  day
# 0  26.1415  548.9715        2  522.83       26.1415     9.1      1    5
# 1   3.8200   80.2200        0   76.40        3.8200     9.6      3    8
# 2  16.2155  340.5255        1  324.31       16.2155     7.4      3    3
# 3  23.2880  489.0480        2  465.76       23.2880     8.4      1   27
# 4  30.2085  634.3785        2  604.17       30.2085     5.3      2    8

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = MinMaxScaler()

# %%
df3.head()
# Out:
#    Branch  City  Customer_type  Gender  Product_line  Unit_price  Quantity  \
# 0       0     2              0       0             3    0.718160         6
# 1       2     1              1       0             0   -1.525303         4
# 2       0     2              1       1             4   -0.352781         6
# 3       0     2              0       1             3    0.096214         7
# 4       0     2              1       1             5    1.156959         6
#
#     Tax_5%     Total  Payment    cogs  gross_income  Rating  month  day
# 0  26.1415  548.9715        2  522.83       26.1415     9.1      1    5
# 1   3.8200   80.2200        0   76.40        3.8200     9.6      3    8
# 2  16.2155  340.5255        1  324.31       16.2155     7.4      3    3
# 3  23.2880  489.0480        2  465.76       23.2880     8.4      1   27
# 4  30.2085  634.3785        2  604.17       30.2085     5.3      2    8

# %%
def scale_data_minmax(data):
    if isinstance (data, pd.Series):
        data = data.to_numpy()
        
    if len(data.shape) == 1:
        data = data.reshape(-1,1)
        
    scaled_data = scaler.fit_transform(data)
    return scaled_data

# %%
df3.Unit_price = scale_data_minmax(df3['Unit_price'])

# %%
df3.head()
# Out:
#    Branch  City  Customer_type  Gender  Product_line  Unit_price  Quantity  \
# 0       0     2              0       0             3    0.718847         6
# 1       2     1              1       0             0    0.057855         4
# 2       0     2              1       1             4    0.403316         6
# 3       0     2              0       1             3    0.535603         7
# 4       0     2              1       1             5    0.848131         6
#
#     Tax_5%     Total  Payment    cogs  gross_income  Rating  month  day
# 0  26.1415  548.9715        2  522.83       26.1415     9.1      1    5
# 1   3.8200   80.2200        0   76.40        3.8200     9.6      3    8
# 2  16.2155  340.5255        1  324.31       16.2155     7.4      3    3
# 3  23.2880  489.0480        2  465.76       23.2880     8.4      1   27
# 4  30.2085  634.3785        2  604.17       30.2085     5.3      2    8

# %%
df4 = df3.copy()

# %%
df4['Tax_5%'] = scale_data_minmax(df4['Tax_5%'])

# %%
df4.head()
# Out:
#    Branch  City  Customer_type  Gender  Product_line  Unit_price  Quantity  \
# 0       0     2              0       0             3    0.718847         6
# 1       2     1              1       0             0    0.057855         4
# 2       0     2              1       1             4    0.403316         6
# 3       0     2              0       1             3    0.535603         7
# 4       0     2              1       1             5    0.848131         6
#
#      Tax_5%     Total  Payment    cogs  gross_income  Rating  month  day
# 0  0.521616  548.9715        2  522.83       26.1415     9.1      1    5
# 1  0.067387   80.2200        0   76.40        3.8200     9.6      3    8
# 2  0.319628  340.5255        1  324.31       16.2155     7.4      3    3
# 3  0.463549  489.0480        2  465.76       23.2880     8.4      1   27
# 4  0.604377  634.3785        2  604.17       30.2085     5.3      2    8

# %%
df4.Total = scale_data_minmax(df4['Total'])

# %%
df4.head()
# Out:
#    Branch  City  Customer_type  Gender  Product_line  Unit_price  Quantity  \
# 0       0     2              0       0             3    0.718847         6
# 1       2     1              1       0             0    0.057855         4
# 2       0     2              1       1             4    0.403316         6
# 3       0     2              0       1             3    0.535603         7
# 4       0     2              1       1             5    0.848131         6
#
#      Tax_5%     Total  Payment    cogs  gross_income  Rating  month  day
# 0  0.521616  0.521616        2  522.83       26.1415     9.1      1    5
# 1  0.067387  0.067387        0   76.40        3.8200     9.6      3    8
# 2  0.319628  0.319628        1  324.31       16.2155     7.4      3    3
# 3  0.463549  0.463549        2  465.76       23.2880     8.4      1   27
# 4  0.604377  0.604377        2  604.17       30.2085     5.3      2    8

# %%
df4.cogs = scale_data_minmax(df4['cogs'])
df4.gross_income = scale_data_minmax(df4['gross_income'])

# %%
df4.head()
# Out:
#    Branch  City  Customer_type  Gender  Product_line  Unit_price  Quantity  \
# 0       0     2              0       0             3    0.718847         6
# 1       2     1              1       0             0    0.057855         4
# 2       0     2              1       1             4    0.403316         6
# 3       0     2              0       1             3    0.535603         7
# 4       0     2              1       1             5    0.848131         6
#
#      Tax_5%     Total  Payment      cogs  gross_income  Rating  month  day
# 0  0.521616  0.521616        2  0.521616      0.521616     9.1      1    5
# 1  0.067387  0.067387        0  0.067387      0.067387     9.6      3    8
# 2  0.319628  0.319628        1  0.319628      0.319628     7.4      3    3
# 3  0.463549  0.463549        2  0.463549      0.463549     8.4      1   27
# 4  0.604377  0.604377        2  0.604377      0.604377     5.3      2    8

# %%
df4.columns
# Out:
# Index(['Branch', 'City', 'Customer_type', 'Gender', 'Product_line',
#        'Unit_price', 'Quantity', 'Tax_5%', 'Total', 'Payment', 'cogs',
#        'gross_income', 'Rating', 'month', 'day'],
#       dtype='object')

# %%
df4.drop(columns = ['Rating','gross_income','Tax_5%','cogs'], inplace=True)

# %%
df4.day = label_encoder.fit_transform(df4['day'])

# %%
df4.head()
# Out:
#    Branch  City  Customer_type  Gender  Product_line  Unit_price  Quantity  \
# 0       0     2              0       0             3    0.718847         6
# 1       2     1              1       0             0    0.057855         4
# 2       0     2              1       1             4    0.403316         6
# 3       0     2              0       1             3    0.535603         7
# 4       0     2              1       1             5    0.848131         6
#
#       Total  Payment  month  day
# 0  0.521616        2      1    4
# 1  0.067387        0      3    7
# 2  0.319628        1      3    2
# 3  0.463549        2      1   26
# 4  0.604377        2      2    7

# %%
##Predictive Modelling
from sklearn.model_selection import train_test_split

# %%
x = df4.drop(columns = 'Total')
y = df4['Total']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state = 101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.9070648958629657

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

cross_val_score(LinearRegression(), x, y, cv=cv)
# Out:
# array([0.89327734, 0.85860236, 0.88911301, 0.87202491, 0.89196778])

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor

def find_best_model_using_gridsearchcv(X,y):
    algos = {
        'linear_regression' : {
            'model': LinearRegression(),
            'params': {
                'normalize': [True, False]
            }
        },
        'lasso': {
            'model': Lasso(),
            'params': {
                'alpha': [1,2],
                'selection': ['random', 'cyclic']
            }
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion' : ['mse','friedman_mse'],
                'splitter': ['best','random']
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

find_best_model_using_gridsearchcv(x,y)
# Out:
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# ...

# %%
##Decision tree giving the best score.....
dt = DecisionTreeRegressor()
dt.fit()
# Out:
# DecisionTreeRegressor()

# %%
dt.predict(x_test)
# Out:
# array([0.15855234, 0.22631584, 0.82346896, 0.27059614, 0.15885758,
#        0.11895241, 0.23531028, 0.50843991, 0.45480907, 0.04973393,
#        0.42226021, 0.14782821, 0.13926111, 0.38572286, 0.0566222 ,
#        0.16465716, 0.37176317, 0.07964755, 0.70945128, 0.33935676,
#        0.73291414, 0.28573609, 0.20010582, 0.25460151, 0.15652758,
#        0.16492171, 0.53735641, 0.0785792 , 0.21809469, 0.04437186,
#        0.32017745, 0.07048014, 0.24620738, 0.35780349, 0.49726809,
#        0.01893512, 0.79742173, 0.52677472, 0.07715475, 0.13401097,
#        0.11147401, 0.21809469, 0.60437716, 0.20054333, 0.58035469,
#        0.5799477 , 0.02080726, 0.79365709, 0.08254734, 0.10383281,
#        0.77513914, 0.25460151, 0.09633406, 0.34770001, 0.73291414,
#        0.71042805, 0.01554694, 0.31962801, 0.25253604, 0.13174201,
#        0.044962  , 0.65703123, 0.11147401, 0.36220913, 0.17423156,
#        0.17391614, 0.2928482 , 0.31253625, 0.2657428 , 0.19107068,
# ...
